# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### **DATASET:**

# %% [markdown]
# grupo de series, *tabla o matriz, puede ser distintos tipos de archivos, es un termino amplio.*

# %% [markdown]
# #### **DATAFRAME**

# %% [markdown]
# Datos ordenados con una estructura especifica, *estructura bidimensional*

# %% [markdown]
# #### **INICIALIZANDO EL DATAFRAME**

# %%
datos = pd.read_csv("assets/data/games.csv", index_col = "id")
datos.head(6)
# Out:
#                                       Title  Release Date  \
# id
# 0                                Elden Ring  Feb 25, 2022
# 1                                     Hades  Dec 10, 2019
# 2   The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                 Undertale  Sep 15, 2015
# 4                             Hollow Knight  Feb 24, 2017
# 5                                 Minecraft  Nov 18, 2011
#
#                                                  Team  Rating Times Listed  \
# id
# 0      ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                ['Supergiant Games']     4.3         2.9K
# 2   ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                  ['tobyfox', '8-4']     4.2         3.5K
# 4                                     ['Team Cherry']     4.4           3K
# 5                                  ['Mojang Studios']     4.3         2.3K
#
# ...

# %% [markdown]
# #### **DIMENSIÓN DEL DATASET**

# %%
np.shape(datos)
# Out:
# (1512, 13)

# %% [markdown]
# #### **INFORMACIÓN**

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1512 entries, 0 to 1511
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1512 non-null   object
#  1   Release Date       1512 non-null   object
#  2   Team               1511 non-null   object
#  3   Rating             1499 non-null   float64
#  4   Times Listed       1512 non-null   object
#  5   Number of Reviews  1512 non-null   object
#  6   Genres             1512 non-null   object
#  7   Summary            1511 non-null   object
#  8   Reviews            1512 non-null   object
#  9   Plays              1512 non-null   object
#  10  Playing            1512 non-null   object
#  11  Backlogs           1512 non-null   object
#  12  Wishlist           1512 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 165.4+ KB

# %% [markdown]
# #### **IDENTIFICANDO DATOS NULOS**

# %%
datos.isnull()
# Out:
#       Title  Release Date   Team  Rating  Times Listed  Number of Reviews  \
# id
# 0     False         False  False   False         False              False
# 1     False         False  False   False         False              False
# 2     False         False  False   False         False              False
# 3     False         False  False   False         False              False
# 4     False         False  False   False         False              False
# ...     ...           ...    ...     ...           ...                ...
# 1507  False         False  False   False         False              False
# 1508  False         False  False   False         False              False
# 1509  False         False  False   False         False              False
# 1510  False         False  False   False         False              False
# 1511  False         False  False   False         False              False
#
#       Genres  Summary  Reviews  Plays  Playing  Backlogs  Wishlist
# id
# ...

# %%
datos.isnull().any()
# Out:
# Title                False
# Release Date         False
# Team                  True
# Rating                True
# Times Listed         False
# Number of Reviews    False
# Genres               False
# Summary               True
# Reviews              False
# Plays                False
# Playing              False
# Backlogs             False
# Wishlist             False
# dtype: bool

# %% [markdown]
# #### **ELIMINANDO DATOS NULOS**

# %%
data_sin_nulos = datos.dropna()
data_sin_nulos
# Out:
#                                         Title  Release Date  \
# id
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    Team  Rating Times Listed  \
# id
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                  ['Supergiant Games']     4.3         2.9K
# ...

# %%
def rpg(genres):
    return "RPG" in genres

#Aplica el filtro
datosRPG = data_sin_nulos[data_sin_nulos["Genres"].apply(rpg)]

#Muestra el dataset con solo algunas columnas
nombresRPG = datosRPG[["Title","Rating"]]
nombresRPG.head(10)
# Out:
#                                       Title  Rating
# id
# 0                                Elden Ring     4.5
# 1                                     Hades     4.3
# 2   The Legend of Zelda: Breath of the Wild     4.4
# 3                                 Undertale     4.2
# 6                                     Omori     4.2
# 9                            NieR: Automata     4.3
# 10                          Persona 5 Royal     4.4
# 12                               God of War     4.2
# 14                               Bloodborne     4.5
# 16                                 Yakuza 0     4.4

# %% [markdown]
# #### **INFORMACIÓN FILTRADA**

# %%
nombresRPG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 516 entries, 0 to 1510
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   516 non-null    object
#  1   Rating  516 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 12.1+ KB

# %% [markdown]
# #### **GRAFICO INENTENDIBLE**

# %%
datasetRPG = nombresRPG.head(10)
datasetRPG.drop(["Title",],axis=1)["Rating"].plot(kind="bar")
# Out:
# <Axes: xlabel='id'>

# %% [markdown]
# #### **GRAFICO DECENTE**

# %%
datasetRPG.set_index("Title", inplace=True)

# %%
datasetRPG["Rating"].plot(x=None, kind="bar")
# Out:
# <Axes: xlabel='Title'>

# %%
ax = datasetRPG["Rating"].plot(x=None, kind="bar")

#agregar etiquetas a las barras
for i, rating in enumerate(datasetRPG["Rating"]):
    ax.annotate(str(rating), xy=(i,rating), ha="center", va="bottom")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### **PROMEDIO RATING VIDEOJUEGOS RPG**

# %%
ratings_RPG = datos[datos["Genres"].apply(lambda x: "RPG" in x)]["Rating"]
promedio_RPG = ratings_RPG.mean()

promedio_RPG
# Out:
# 3.832558139534884

# %% [markdown]
# #### **Aplicar  para calcular promedio de Indies**

# %%
ratings_indie = datos[datos["Genres"].apply(lambda x: "Indie" in x)]["Rating"]
promedio_indie = ratings_indie.mean()

promedio_indie
# Out:
# 3.7031802120141344

# %% [markdown]
# #### **JUNTAR PROMEDIOS EN UN DATASET**

# %%
dataset_promedios = pd.DataFrame({"Genero": ["RPG", "Indie"], "Promedio":[promedio_RPG, promedio_indie]})

# %%
plt.pie(dataset_promedios["Promedio"], labels=dataset_promedios["Genero"], autopct="%1.1f%%")
plt.title("Promedio de Rating por Género")
plt.show()

# %% [markdown]
# #### **TAREA**

# %% [markdown]
# ### **1**

# %%
ratings_plataformas = datos[datos["Genres"].apply(lambda x: "Platform" in x)]["Rating"]
promedio_plataformas = ratings_plataformas.mean()

ratings_aventura = datos[datos["Genres"].apply(lambda x: "Adventure" in x)]["Rating"]
promedio_aventura = ratings_aventura.mean()

dataset_promedios = pd.DataFrame({"Genero": ["RPG", "Indie", "Plataformas", "Aventura"], "Promedio":[promedio_RPG, promedio_indie, promedio_plataformas, promedio_aventura]})

plt.pie(dataset_promedios["Promedio"], labels=dataset_promedios["Genero"], autopct="%1.1f%%")
plt.title("Promedio de Rating por Género")
plt.show()

# %% [markdown]
# ### **2**

# %%
datos_nulos_reemplazados = datos.fillna(0)
datos_nulos_reemplazados.isnull().any()
# Out:
# Title                False
# Release Date         False
# Team                 False
# Rating               False
# Times Listed         False
# Number of Reviews    False
# Genres               False
# Summary              False
# Reviews              False
# Plays                False
# Playing              False
# Backlogs             False
# Wishlist             False
# dtype: bool

# %% [markdown]
# ### **3**

# %%
peores_ratings = datos.nsmallest(10, "Rating")

# %%
peores_ratings.set_index("Title", inplace=True)

ax = peores_ratings["Rating"].plot(x=None, kind="bar")

#agregar etiquetas a las barras
for i, rating in enumerate(peores_ratings["Rating"]):
    ax.annotate(str(rating), xy=(i,rating), ha="center", va="bottom")

# %% [markdown]
# ### **4**

# %%
datos_nulos_reemplazados.to_csv("assets\data\GamesNoNulls.csv")

# %% [markdown]
# #### **PRUEBAS**

# %%
datazos = pd.read_csv("assets/data/GamesNoNulls.csv", index_col = "id")
datazos.head(6)
# Out:
#                                       Title  Release Date  \
# id
# 0                                Elden Ring  Feb 25, 2022
# 1                                     Hades  Dec 10, 2019
# 2   The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                 Undertale  Sep 15, 2015
# 4                             Hollow Knight  Feb 24, 2017
# 5                                 Minecraft  Nov 18, 2011
#
#                                                  Team  Rating Times Listed  \
# id
# 0      ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                ['Supergiant Games']     4.3         2.9K
# 2   ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                  ['tobyfox', '8-4']     4.2         3.5K
# 4                                     ['Team Cherry']     4.4           3K
# 5                                  ['Mojang Studios']     4.3         2.3K
#
# ...

# %%
datazos.isnull().any()
# Out:
# Title                False
# Release Date         False
# Team                 False
# Rating               False
# Times Listed         False
# Number of Reviews    False
# Genres               False
# Summary              False
# Reviews              False
# Plays                False
# Playing              False
# Backlogs             False
# Wishlist             False
# dtype: bool

# %%
datazos.sort_values(by="Rating", ascending=False).head()
# Out:
#                                          Title     Release Date  \
# id
# 1252         Elden Ring: Shadow of the Erdtree  releases on TBD
# 1090         The Great Ace Attorney 2: Resolve     Aug 03, 2017
# 1153                            Dwarf Fortress     Dec 06, 2022
# 1104  Sekiro: Shadows Die Twice - GOTY Edition     Oct 28, 2020
# 43                                 Outer Wilds     May 28, 2019
#
#                                                 Team  Rating Times Listed  \
# id
# 1252  ['FromSoftware', 'Bandai Namco Entertainment']     4.8           18
# 1090                                      ['Capcom']     4.6          386
# 1153                ['Bay 12 Games', 'Kitfox Games']     4.6           48
# 1104                  ['Activision', 'FromSoftware']     4.6          173
# 43       ['Mobius Digital', 'Annapurna Interactive']     4.6         1.8K
#
#      Number of Reviews                                             Genres  \
# id
# ...

# %%
datos.isnull().sum()

# %%
len(datos)
# Out:
# 1512

# %%
# Out:
# Title                1512
# Release Date         1512
# Team                 1511
# Rating               1499
# Times Listed         1512
# Number of Reviews    1512
# Genres               1512
# Summary              1511
# Reviews              1512
# Plays                1512
# Playing              1512
# Backlogs             1512
# Wishlist             1512
# dtype: int64
